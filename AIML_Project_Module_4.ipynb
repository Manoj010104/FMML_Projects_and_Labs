# %% [markdown]
# <a href="https://colab.research.google.com/github/Manoj010104/FMML_Projects_and_Labs/blob/main/AIML_Project_Module_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project for Module 4: Perceptron and Gradient Descent
#
# NOTE: YOU NEED TO WRITE CODE IN CELLS THAT SPECIFICALLY MENTION TASK-1, TASK-2, etc.
#
# WRITE ANY OBSERVATION(S), IF REQUIRED BY THE TASK, IN A SEPARATE CELL AT THE BOTTOM OF THE NOTEBOOK.
#
# ---

# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # color map

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# # Example 1 - A simple cost function
#
# ## $$f(x) = x^2 + x + 1$$

# %%
def f(x):
    return x ** 2 + x + 1

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
# Plot
plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# ## Slope & Derivatives
#
# Creating a function for the derivative of $f(x)$ called df(x)

# %%
def df(x):
    return 2 * x + 1

# %%
# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = df(previous_x)
    # [REQUIRED] Calculate the gradient
    new_x = previous_x - step_multiplier * gradient
    # [REQUIRED] Update the new_x value

    step_size = abs(new_x - previous_x)
    # print(step_size)

    x_list.append(new_x)
    slope_list.append(df(new_x))
     # [REQUIRED] Append the slope value

    if step_size < precision:
        print('Converged after', n, 'iterations')
         # [REQUIRED] Update the print statement
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# Converged after 50 iterations
# Local minimum occurs at: -0.49996003706460423
# Slope or df(x) value at this point is: 7.992587079153068e-05
# f(x) value or cost at this point is: 0.7500000015970362

# %% [markdown]
# ***CHANGES DONE TO THE EXISTING CODE:***
# 1. **Gradient Calculation:**
#    - Original: `gradient = ## [REQUIRED]`
#    - Change: gradient = df(previous_x)  # [REQUIRED] Calculate the gradient`
#    - Observation: Calculating the gradient using the provided derivative function.
#
# 2. **Update Rule:**
#    - Original: `new_x = ## [REQUIRED]`
#    - Change: `new_x = previous_x - step_multiplier * gradient  # [REQUIRED] Update the new_x value`
#    - Observation: Updating the new value of `x` using the gradient descent update rule.
#
# 3. **Appending Slope Values:**
#    - Original: `slope_list.append## [REQUIRED])`
#    - Change: `slope_list.append(df(new_x))  # [REQUIRED] Append the slope value`
#    - Observation: Appending slope (derivative) values for visualization.

# %%
# Superimpose the gradient descent calculations on plot

plt.figure(figsize=[20, 5])

# 1 Chart: Cost function
plt.subplot(1, 3, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)

values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 3, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)

# 3 Chart: Derivative (Close Up)
plt.subplot(1, 3, 3)

plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()
plt.xlim(-0.55, -0.2)
plt.ylim(-0.3, 0.8)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)


plt.show()

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess & Advanced Functions
#
# ## $$g(x) = x^4 - 4x^2 + 5$$

# %% [markdown]
# **Completed example two with the given input question**

# %%
# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return x**4 - 4*x**2 + 5  # [REQUIRED] Define the function g(x)

def dg(x):
    return 4*x**3 - 8*x  # [REQUIRED] Define the derivative of g(x)

# %%
## TASK-3 : Plot function and derivative side by side like has been done earlier

# Generate x values for plotting
x_1 = np.linspace(-2, 2, 400)

# Set up the plot
plt.figure(figsize=[20, 5])

# 1 Chart: Cost function
plt.subplot(1, 3, 1)
plt.xlim(-2, 2)
plt.ylim(0, 8)
plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_1, g(x_1), color='blue', linewidth=3, alpha=0.8)

# Initial point for gradient descent
x_start = 1.5

# Run gradient descent and get the values
x_list = gradient_descent(x_start, learning_rate=0.1, n_iterations=20)

# Plot the points on the cost function
values = np.array(x_list)
plt.scatter(x_list, g(values), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 3, 2)
plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)/dx', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-10, 10)
plt.plot(x_1, dg_dx(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, dg_dx(values), color='red', s=100, alpha=0.5)

# 3 Chart: Gradient Descent (Close Up)
plt.subplot(1, 3, 3)
plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-10, 10)
plt.plot(x_1, dg_dx(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, dg_dx(values), color='red', s=300, alpha=0.6)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001,
                    max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.02, 0.001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 1.4122375085019094
# Number of steps: 23

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.5,
                                                 multiplier=0.01, precision=0.0001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -1.4137636556157256
# Number of steps: 56

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.1)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -1.4120887490901561
# Number of steps: 34

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 0)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

# %% [markdown]
# # Example 3 - Divergence and Overflow
#
# ## $$h(x) = x^5 - 2x^4 + 2$$

# %% [markdown]
# **Completed the example three divergence and overflow for the given input question**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the cost function g(x) and its derivative dg(x)/dx
def g(x):
    return x**2 + x + 1

def dg(x):
    return 2*x + 1

def numerical_derivative(func, x, epsilon=1e-6):
    return (func(x + epsilon) - func(x - epsilon)) / (2 * epsilon)

# Gradient Descent function
def gradient_descent(func, initial_guess, multiplier=0.02, precision=0.001, max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [numerical_derivative(func, new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = numerical_derivative(func, previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(numerical_derivative(func, new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# %% [markdown]
# # The Learning Rate

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(func=g, initial_guess=1.9,
                                                  multiplier=0.02, precision=0.001, max_iter=500)

# Plot function and derivative and scatter plot side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

# Use the cost function g(x) for plotting
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

# Use the derivative function dg(x) for plotting
plt.plot(x_2, numerical_derivative(g, x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Number of steps is: ', len(list_x))
# Out:
# Number of steps is:  114

# %%
print(" Task-5: Run gradient descent 3 times")
# Task-5: Run gradient descent 3 times
local_min_1, list_x_1, deriv_list_1 = gradient_descent(func=g, initial_guess=0.5, multiplier=0.02, precision=0.001, max_iter=500)
local_min_2, list_x_2, deriv_list_2 = gradient_descent(func=g, initial_guess=-1.5, multiplier=0.02, precision=0.001, max_iter=500)
local_min_3, list_x_3, deriv_list_3 = gradient_descent(func=g, initial_guess=2.5, multiplier=0.02, precision=0.001, max_iter=500)
print("3 GRADIENT DESCENTS")
# Print the results
print('Results for Run 1:')
print('Local min occurs at:', local_min_1)
print('Number of steps:', len(list_x_1))
print('\nResults for Run 2:')
print('Local min occurs at:', local_min_2)
print('Number of steps:', len(list_x_2))
print('\nResults for Run 3:')
print('Local min occurs at:', local_min_3)
print('Number of steps:', len(list_x_3))
n = 100
# TASK-6: Plot two more learning rates: mid_gamma (0.001) and high_gamma (0.002)
# Low gamma
low_gamma = gradient_descent(func=g, initial_guess=3, multiplier=0.0005, precision=0.001, max_iter=n)

# Mid gamma
mid_gamma = gradient_descent(func=g, initial_guess=3, multiplier=0.001, precision=0.001, max_iter=n)

# High gamma
high_gamma = gradient_descent(func=g, initial_guess=3, multiplier=0.002, precision=0.001, max_iter=n)

# Experiment
insane_gamma = gradient_descent(func=g, initial_guess=1.9, multiplier=0.25, precision=0.001, max_iter=n)

# Task-6: Plot the results for three different learning rates
print(" TASK-6 Plot two more learning rates: mid_gamma (0.001) and high_gamma (0.002)")
plt.figure(figsize=[20, 5])

# Low gamma
plt.subplot(1, 4, 1)
plt.xlim(-2, 4)
plt.ylim(0, 10)
plt.title('Low Gamma (0.0005)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(low_gamma[1], g(np.array(low_gamma[1])), color='red', s=100, alpha=0.6)

# Mid gamma
plt.subplot(1, 4, 2)
plt.xlim(-2, 4)
plt.ylim(0, 10)
plt.title('Mid Gamma (0.001)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(mid_gamma[1], g(np.array(mid_gamma[1])), color='red', s=100, alpha=0.6)

# High gamma
plt.subplot(1, 4, 3)
plt.xlim(-2, 4)
plt.ylim(0, 10)
plt.title('High Gamma (0.002)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(high_gamma[1], g(np.array(high_gamma[1])), color='red', s=100, alpha=0.6)

# Insane gamma
plt.subplot(1, 4, 4)
plt.xlim(-2, 4)
plt.ylim(0, 10)
plt.title('Insane Gamma (0.25)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(insane_gamma[1], g(np.array(insane_gamma[1])), color='red', s=100, alpha=0.6)

plt.tight_layout()
plt.show()

# Display the number of steps for each experiment
print('Number of steps for Low Gamma: ', len(low_gamma[1]))
print('Number of steps for Mid Gamma: ', len(mid_gamma[1]))
print('Number of steps for High Gamma: ', len(high_gamma[1]))
print('Number of steps for Insane Gamma: ', len(insane_gamma[1]))
# Out:
#  Task-5: Run gradient descent 3 times
# 3 GRADIENT DESCENTS
# Results for Run 1:
# Local min occurs at: -0.47661413492877713
# Number of steps: 93
#
# Results for Run 2:
# Local min occurs at: -0.5233858650712229
# Number of steps: 93
#
# Results for Run 3:
# Local min occurs at: -0.4766977430711883
# Number of steps: 120
#  TASK-6 Plot two more learning rates: mid_gamma (0.001) and high_gamma (0.002)
# Number of steps for Low Gamma:  101
# Number of steps for Mid Gamma:  101
# Number of steps for High Gamma:  101
# Number of steps for Insane Gamma:  13

# %%
## TASK-7 : Plot reduction in cost for each iteration

print (" Task-7: Plot reduction in cost for each iteration")
plt.figure(figsize=[15, 5])

# Low gamma
plt.subplot(1, 4, 1)
plt.title('Cost Reduction (Low Gamma)', fontsize=17)
plt.xlabel('Iteration', fontsize=16)
plt.ylabel('Cost', fontsize=16)
plt.plot(range(len(low_gamma[2])), low_gamma[2], color='green', linewidth=2)

# Mid gamma
plt.subplot(1, 4, 2)
plt.title('Cost Reduction (Mid Gamma)', fontsize=17)
plt.xlabel('Iteration', fontsize=16)
plt.ylabel('Cost', fontsize=16)
plt.plot(range(len(mid_gamma[2])), mid_gamma[2], color='green', linewidth=2)

# High gamma
plt.subplot(1, 4, 3)
plt.title('Cost Reduction (High Gamma)', fontsize=17)
plt.xlabel('Iteration', fontsize=16)
plt.ylabel('Cost', fontsize=16)
plt.plot(range(len(high_gamma[2])), high_gamma[2], color='green', linewidth=2)

# Insane gamma
plt.subplot(1, 4, 4)
plt.title('Cost Reduction (Insane Gamma)', fontsize=17)
plt.xlabel('Iteration', fontsize=16)
plt.ylabel('Cost', fontsize=16)
plt.plot(range(len(insane_gamma[2])), insane_gamma[2], color='green', linewidth=2)

plt.tight_layout()
plt.show()
# Out:
#  Task-7: Plot reduction in cost for each iteration

# %% [markdown]
# # Example 4 - Data Viz with 3D Charts
#
# ## Minimise $$f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$$
#
# Minimise $$f(x, y) = \frac{1}{r + 1}$$ where $r$ is $3^{-x^2 - y^2}$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Cost function
def f(x, y):
    r = 3 - x**2 - y**2
    return 1 / (r + 1)

# Partial derivatives with respect to x and y
def df_dx(x, y):
    r = 3 - x**2 - y**2
    return (2 * x) / ((r + 1)**2)

def df_dy(x, y):
    r = 3 - x**2 - y**2
    return (2 * y) / ((r + 1)**2)

# Gradient Descent
def gradient_descent_2d(x, y, learning_rate, precision, max_iter):
    x_list = [x]
    y_list = [y]

    for _ in range(max_iter):
        x_new = x - learning_rate * df_dx(x, y)
        y_new = y - learning_rate * df_dy(x, y)

        step_size = np.sqrt((x_new - x)**2 + (y_new - y)**2)

        x_list.append(x_new)
        y_list.append(y_new)

        if step_size < precision:
            break

        x, y = x_new, y_new

    return x_new, y_new, x_list, y_list

# Initial values
initial_x = 2
initial_y = -2

# Gradient Descent function call
final_x, final_y, x_list, y_list = gradient_descent_2d(initial_x, initial_y, learning_rate=0.1, precision=0.00001, max_iter=500)

# Create a meshgrid
x_vals = np.linspace(-3, 3, 100)
y_vals = np.linspace(-3, 3, 100)
x_mesh, y_mesh = np.meshgrid(x_vals, y_vals)

# Evaluate the cost function on the meshgrid
z_mesh = f(x_mesh, y_mesh)

# Plotting
# 1 Chart: Cost function
fig = plt.figure(figsize=[15, 5])

ax1 = fig.add_subplot(1, 3, 1, projection='3d')
ax1.set_title('Cost function')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('f(x, y)')
ax1.plot_surface(x_mesh, y_mesh, z_mesh, cmap='viridis', alpha=0.8)

# 2 Chart: Partial Derivatives
ax2 = fig.add_subplot(1, 3, 2, projection='3d')
ax2.set_title('Partial Derivative df/dx')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('df/dx')
ax2.plot_surface(x_mesh, y_mesh, df_dx(x_mesh, y_mesh), cmap='plasma', alpha=0.8)

ax3 = fig.add_subplot(1, 3, 3, projection='3d')
ax3.set_title('Partial Derivative df/dy')
ax3.set_xlabel('X')
ax3.set_ylabel('Y')
ax3.set_zlabel('df/dy')
ax3.plot_surface(x_mesh, y_mesh, df_dy(x_mesh, y_mesh), cmap='plasma', alpha=0.8)

plt.show()

# Print the results
print('Local minimum occurs at (x, y):', final_x, final_y)
print('f(x, y) value at this point is:', f(final_x, final_y))
# Out:
# Local minimum occurs at (x, y): 0.0006206593024851216 -0.0006206593024851216
# f(x, y) value at this point is: 0.2500000481522555

# %%
# Make our x and y data
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

print('Shape of X array', x_4.shape)

x_4, y_4 = np.meshgrid(x_4, y_4)
print('Array after meshgrid: ', x_4.shape)
# Out:
# Shape of X array (200,)
# Array after meshgrid:  (200, 200)

# %%
# Generating 3D Plot
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)

plt.show()

# %% [markdown]
# ##########################
# ##########################
#
# ## TASK-9 : Complete the lines of text wherever marked as [REQUIRED] in this cell.
#
# ##########################
# ##########################
#
# ## Partial Derivatives & Symbolic Computation
#
# ## $$\frac{\partial f}{\partial x} = ## [REQUIRED]
#
# ## $$\frac{\partial f}{\partial y} = ## [REQUIRED]

# %%
a, b = symbols('x, y')
print('Our cost function f(x, y) is: ', f(a, b))
print('Partial derivative wrt x is: ', diff(f(a, b), b))
print('Value of f(x,y) at x=1.8 y=1.0 is: ',
      f(a, b).evalf(subs={a:1.8, b:1.0})) # Python Dictionary
print('Value of partial derivative wrt x: ', diff(f(a, b), a).evalf(subs={a:1.8, b:1.0}))
# Out:
# Our cost function f(x, y) is:  1/(-x**2 - y**2 + 4)
# Partial derivative wrt x is:  2*y/(-x**2 - y**2 + 4)**2
# Value of f(x,y) at x=1.8 y=1.0 is:  -4.16666666666666
# Value of partial derivative wrt x:  62.4999999999999

# %% [markdown]
# ## Batch Gradient Descent with SymPy

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = diff(f(a, b), a).evalf(subs={a:params[0], b:params[1]})
    gradient_y = diff(f(a, b), b).evalf(subs={a:params[0], b:params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# Values in gradient array [0.0774079397932183 0.0430044109962325]
# Minimum occurs at x value of:  0.508314391458292
# Minimum occurs at y value of:  0.282396884143496
# The cost is:  0.273084630336428

# %%
##########################
##########################

## TASK-10 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################
# Partial derivative functions example 4
def fpx(x, y):
    r = 3 - x**2 - y**2
    return (-2 * x) / (r + 1)**2

def fpy(x, y):
    r = 3 - x**2 - y**2
    return (-2 * y) / (r + 1)**2

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# Values in gradient array [-0.00235207 -0.00130671]
# Minimum occurs at x value of:  8.17015479443108
# Minimum occurs at y value of:  4.5389748857950565
# The cost is:  -0.011997064695623205

# %% [markdown]
# ## Graphing 3D Gradient Descent

# %%
# Setup
multiplier = 0.1
max_iter = 200
params = np.array([1.8, 1.0]) # initial guess
values_array = params.reshape(1, 2)
print(values_array.shape)

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
    #values_array = np.append(values_array, params.reshape(1, 2), axis=0)
    values_array = np.concatenate((values_array, params.reshape(1, 2)), axis=0)


# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# (1, 2)
# Values in gradient array [-0.00241909 -0.00134394]
# Minimum occurs at x value of:  8.098601781645009
# Minimum occurs at y value of:  4.499223212025013
# The cost is:  -0.012220403233909312

# %%
# Generating 3D Plot
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)
ax.scatter(values_array[:, 0], values_array[:, 1],
           f(values_array[:, 0], values_array[:, 1]), s=50, color='red')

plt.show()

# %% [markdown]
# ## For Reference, practice and play with the code below
#
# # Example 5 - Working with Data & a Real Cost Function
#
# ## Mean Squared Error: a cost function for regression problems
#
# ### $$RSS = \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y - \hat{y} \big)^2 $$

# %%
# Make sample data
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

print('Shape of x_5 array:', x_5.shape)
print('Shape of y_5 array:', y_5.shape)
# Out:
# Shape of x_5 array: (7, 1)
# Shape of y_5 array: (7, 1)

# %%
# Quick linear regressino
regr = LinearRegression()
regr.fit(x_5, y_5)
print('Theta 0:', regr.intercept_[0])
print('Theta 1:', regr.coef_[0][0])
# Out:
# Theta 0: 0.8475351486029545
# Theta 1: 1.2227264637835913

# %%
plt.scatter(x_5, y_5, s=50)
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)
plt.xlabel('x values')
plt.ylabel('y values')
plt.show()

# %%
# y_hat = theta0 + theta1*x
y_hat = 0.847535148603 + 1.22272646378*x_5
print('Est values y_hat are: \n', y_hat)
print('In comparison, the actual y values are \n', y_5)
# Out:
# Est values y_hat are:
#  [[0.96980779]
#  [2.31480691]
#  [3.78207866]
#  [4.76025983]
#  [5.86071365]
#  [7.81707599]
#  [8.79525716]]
# In comparison, the actual y values are
#  [[1.7]
#  [2.4]
#  [3.5]
#  [3. ]
#  [6.1]
#  [9.4]
#  [8.2]]

# %%
# Challenge: Write a python function mse(y, y_hat) returns the MSE? Call the mse(y, y_hat)
# function and print out the MSE for the y_hat calculated above.

def mse(y, y_hat):
    mse_calc = np.average((y - y_hat)**2, axis=0)
    return mse_calc

# Assuming y and y_hat are defined somewhere
# For example:
y_actual = np.array([1, 2, 3, 4, 5, 6, 7])
y_predicted = np.array([1.2, 2.5, 2.8, 3.7, 4.5, 5.8, 7.2])

# Call mse function and print the result
mse_result = mse(y_actual, y_predicted)
print(f'Mean Squared Error: {mse_result}')
# Out:
# Mean Squared Error: 0.10714285714285714

# %%
print('Manually calculated MSE is:', mse(y_5, y_hat))
print('MSE regression using manual calc is', mean_squared_error(y_5, y_hat))
print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# Manually calculated MSE is: [0.94796558]
# MSE regression using manual calc is 0.947965575979458
# MSE regression is 0.9479655759794577

# %% [markdown]
# ## 3D Plot for the MSE Cost Function
#
# ### Make data for thetas

# %%
nr_thetas = 200
th_0 = np.linspace(start=-1, stop=3, num=nr_thetas)
th_1 = np.linspace(start=-1, stop=3, num=nr_thetas)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %% [markdown]
# ### Calc MSE using nested for loops

# %%
plot_cost = np.zeros((nr_thetas, nr_thetas))

for i in range(nr_thetas):
    for j in range(nr_thetas):
        #print(plot_t0[j][i])
        y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
        plot_cost[i][j] = mse(y_5, y_hat)

print('Shape of plot_t0', plot_t0.shape)
print('Shape of plot_t1', plot_t1.shape)
print('Shape of plot_cost', plot_cost.shape)
# Out:
# Shape of plot_t0 (200, 200)
# Shape of plot_t1 (200, 200)
# Shape of plot_cost (200, 200)

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot)
plt.show()

# %%
print('Min value of plot_cost', plot_cost.min())
ij_min = np.unravel_index(plot_cost.argmin(), plot_cost.shape)
print('Min occurs at (i,j):', ij_min)
print('Min MSE for Theta 0 at plot_t0[111][91]', plot_t0[ij_min[0]][ij_min[1]])
print('Min MSE for Theta 1 at plot_t1[111][91]', plot_t1[ij_min[0]][ij_min[1]])
# Out:
# Min value of plot_cost 0.9483826526747164
# Min occurs at (i,j): (111, 91)
# Min MSE for Theta 0 at plot_t0[111][91] 0.829145728643216
# Min MSE for Theta 1 at plot_t1[111][91] 1.2311557788944723

# %% [markdown]
# ## Partial Derivatives of MSE w.r.t. $\theta_0$ and $\theta_1$
#
# ## $$\frac{\partial MSE}{\partial \theta_0} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)$$
#
# ## $$\frac{\partial MSE}{\partial \theta_1} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big( x^{(i)} \big)$$

# %% [markdown]
# ## MSE & Gradient Descent

# %%
# x values, y values, array of theta parameters (theta0 at index 0 and theta1 at index 1)
def grad(x, y, thetas):
    n = y.size

    # Challenge: Create theta0_slope and theta1_slope to hold slope values from partial derivs
    theta0_slope = (-2/n) * sum(y - thetas[0] - thetas[1]*x)
    theta1_slope = (-2/n) * sum((y - thetas[0] - thetas[1]*x) * x)

    #return np.array([theta0_slope[0], theta1_slope[0]])
    #return np.append(arr=theta0_slope, values=theta1_slope)
    return np.concatenate((theta0_slope, theta1_slope), axis=0)

# %%
multiplier = 0.01
thetas = np.array([2.9, 2.9])

# Collect data points for scatter plot
plot_vals = thetas.reshape(1, 2)
mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5)

for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)

    # Append the new values to our numpy arrays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1, 2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1]*x_5))

# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# Min occurs at Theta 0: 0.8532230461743415
# Min occurs at Theta 1: 1.2214935332607393
# MSE is: [0.94797511]

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
plt.show()
